# %%
pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\bedar\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: lxml in c:\users\bedar\anaconda3\lib\site-packages (from pandas-datareader) (4.9.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\bedar\anaconda3\lib\site-packages (from pandas-datareader) (2.1.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\bedar\anaconda3\lib\site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\bedar\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bedar\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bedar\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bedar\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bedar\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bedar\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bedar\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bedar\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2023.7.22)
# Requirement already satisfied: six>=1.5 in c:\users\bedar\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential 
from keras.layers import Dense, LSTM  # importing layers package , Dense layer is used to connect all layers
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
import pandas_datareader as data

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (0.2.28)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from yfinance) (2023.3)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\goelp\appdata\roaming\python\python311\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from requests>=2.31->yfinance) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\goelp\anaconda3\envs\pythonandr\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("C:\\Users\\goelp\\Desktop\\SCIT Classroom material\\ASSIGNMENTS DONE BY ME\\Finance\\DLF EPS.csv")

# %%
df.shape
# Out:
# (2473, 4)

# %%
df = pd.DataFrame.dropna(df)

# %%
plt.figure(figsize=(12,6))
plt.title('EPS')
plt.plot(df['EPS'])
plt.xlabel('Date',fontsize=18)
plt.ylabel('EPS RS')
plt.show()

# %%
data = df.filter(['EPS'])
dataset = data.values
training_data_len = math.ceil(len(dataset)*0.80)  #Math. ceil() method rounds a number rounded UP to the nearest integer.
training_data_len
# Out:
# 1979

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[-2.26990137],
#        [-2.26990137],
#        [-2.26990137],
#        ...,
#        [ 1.65456497],
#        [ 1.65590579],
#        [ 1.6572466 ]])

# %%
train_data = scaled_data[0:training_data_len, :]
x_train = []
y_train = []

for i in range(120, len(train_data)):
    x_train.append(train_data[i-70:i,0])
    y_train.append(train_data[i,0])
    if i <= 70:
        print(x_train)
        print(y_train)
        print()

# %%
x_train,y_train = np.array(x_train), np.array(y_train)
x_train.shape
# Out:
# (1859, 70)

# %%
x_train.shape[0],x_train.shape[1]
# Out:
# (1859, 70)

# %%
sample=float(x_train.shape[0])

# %%
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1859, 70, 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss = 'mean_squared_error')

# %%
model.fit(x_train,y_train, batch_size=60, epochs = 70)
# Out:
# Epoch 1/70
# 31/31 [==============================] - 5s 51ms/step - loss: 0.1233
# Epoch 2/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0184
# Epoch 3/70
# 31/31 [==============================] - 2s 53ms/step - loss: 0.0145
# Epoch 4/70
# 31/31 [==============================] - 2s 51ms/step - loss: 0.0123
# Epoch 5/70
# 31/31 [==============================] - 2s 51ms/step - loss: 0.0113
# Epoch 6/70
# 31/31 [==============================] - 2s 51ms/step - loss: 0.0106
# Epoch 7/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0099
# Epoch 8/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0104
# Epoch 9/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0099
# Epoch 10/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0091
# Epoch 11/70
# 31/31 [==============================] - 1s 48ms/step - loss: 0.0080
# Epoch 12/70
# 31/31 [==============================] - 2s 48ms/step - loss: 0.0077
# Epoch 13/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0077
# Epoch 14/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0072
# Epoch 15/70
# 31/31 [==============================] - 2s 52ms/step - loss: 0.0067
# Epoch 16/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0069
# Epoch 17/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0063
# Epoch 18/70
# 31/31 [==============================] - 2s 48ms/step - loss: 0.0058
# Epoch 19/70
# 31/31 [==============================] - 2s 48ms/step - loss: 0.0058
# Epoch 20/70
# 31/31 [==============================] - 1s 48ms/step - loss: 0.0062
# Epoch 21/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0055
# Epoch 22/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0057
# Epoch 23/70
# 31/31 [==============================] - 2s 51ms/step - loss: 0.0058
# Epoch 24/70
# 31/31 [==============================] - 2s 53ms/step - loss: 0.0047
# Epoch 25/70
# 31/31 [==============================] - 2s 51ms/step - loss: 0.0046
# Epoch 26/70
# 31/31 [==============================] - 2s 53ms/step - loss: 0.0046
# Epoch 27/70
# 31/31 [==============================] - 2s 50ms/step - loss: 0.0046
# Epoch 28/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0043
# Epoch 29/70
# 31/31 [==============================] - 1s 48ms/step - loss: 0.0047
# Epoch 30/70
# 31/31 [==============================] - 2s 50ms/step - loss: 0.0041
# Epoch 31/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0042
# Epoch 32/70
# 31/31 [==============================] - 2s 57ms/step - loss: 0.0042
# Epoch 33/70
# 31/31 [==============================] - 2s 51ms/step - loss: 0.0043
# Epoch 34/70
# 31/31 [==============================] - 2s 52ms/step - loss: 0.0044
# Epoch 35/70
# 31/31 [==============================] - 2s 56ms/step - loss: 0.0042
# Epoch 36/70
# 31/31 [==============================] - 2s 54ms/step - loss: 0.0039
# Epoch 37/70
# 31/31 [==============================] - 2s 53ms/step - loss: 0.0040
# Epoch 38/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0041
# Epoch 39/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0040
# Epoch 40/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0040
# Epoch 41/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0039
# Epoch 42/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0039
# Epoch 43/70
# 31/31 [==============================] - 2s 52ms/step - loss: 0.0038
# Epoch 44/70
# 31/31 [==============================] - 2s 51ms/step - loss: 0.0041
# Epoch 45/70
# 31/31 [==============================] - 2s 50ms/step - loss: 0.0039
# Epoch 46/70
# 31/31 [==============================] - 2s 51ms/step - loss: 0.0039
# Epoch 47/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0040
# Epoch 48/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0040
# Epoch 49/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0039
# Epoch 50/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0038
# Epoch 51/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0038
# Epoch 52/70
# 31/31 [==============================] - 1s 48ms/step - loss: 0.0038
# Epoch 53/70
# 31/31 [==============================] - 2s 50ms/step - loss: 0.0037
# Epoch 54/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0038
# Epoch 55/70
# 31/31 [==============================] - 2s 50ms/step - loss: 0.0037
# Epoch 56/70
# 31/31 [==============================] - 2s 50ms/step - loss: 0.0037
# Epoch 57/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0037
# Epoch 58/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0041
# Epoch 59/70
# 31/31 [==============================] - 2s 50ms/step - loss: 0.0039
# Epoch 60/70
# 31/31 [==============================] - 2s 54ms/step - loss: 0.0040
# Epoch 61/70
# 31/31 [==============================] - 2s 58ms/step - loss: 0.0038
# Epoch 62/70
# 31/31 [==============================] - 2s 63ms/step - loss: 0.0039
# Epoch 63/70
# 31/31 [==============================] - 2s 56ms/step - loss: 0.0040
# Epoch 64/70
# 31/31 [==============================] - 2s 52ms/step - loss: 0.0039
# Epoch 65/70
# 31/31 [==============================] - 2s 49ms/step - loss: 0.0040
# Epoch 66/70
# 31/31 [==============================] - 2s 52ms/step - loss: 0.0038
# Epoch 67/70
# 31/31 [==============================] - 2s 55ms/step - loss: 0.0038
# Epoch 68/70
# 31/31 [==============================] - 2s 55ms/step - loss: 0.0036
# Epoch 69/70
# 31/31 [==============================] - 2s 55ms/step - loss: 0.0040
# Epoch 70/70
# 31/31 [==============================] - 2s 55ms/step - loss: 0.0040

# %%
test_data = scaled_data[training_data_len - 70: , :]
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(70, len(test_data)):
    x_test.append(test_data[i-70:i, 0])

# %%
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 16/16 [==============================] - 0s 12ms/step

# %%
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date',fontsize=18)
plt.ylabel('price in rs',fontsize=18)
plt.plot(train['EPS'])
plt.plot(valid[['EPS','Predictions']])
plt.legend(['Train','Val','Predictions'], loc='lower right')
plt.show()
# Out:
# C:\Users\goelp\AppData\Local\Temp\ipykernel_26460\3641130845.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
EPS = valid.iloc[-1,:-1].values
EPS = EPS.tolist()
EPS_p = EPS[0]
predict = valid.iloc[-1,1:].values
predict = predict.tolist()
predict_p = predict[0]

# %%
Error = (abs(predict_p - EPS_p)/(EPS_p))*100
print('The error rate between actual close and predicted close is ', Error)
# Out:
# The error rate between actual close and predicted close is  0.7266247779328608

# %%
pwd
# Out:
# 'C:\\Users\\goelp\\Desktop\\SCIT Classroom material\\ASSIGNMENTS DONE BY ME\\Finance'

# %%
valid
# Out:
#             EPS  Predictions
# 1979   9.587774     9.579592
# 1980   9.590901     9.582659
# 1981   9.594028     9.585726
# 1982   9.597155     9.588793
# 1983   9.600283     9.591860
# ...         ...          ...
# 2468  11.117003    11.037243
# 2469  11.120130    11.040093
# 2470  11.123257    11.042944
# 2471  11.126385    11.045793
# 2472  11.129512    11.048642
#
# [494 rows x 2 columns]

# %%
valid.to_csv("C:\\Users\\goelp\\Desktop\\SCIT Classroom material\\ASSIGNMENTS DONE BY ME\\Finance\\DLF EPS preds.csv",encoding='utf-8')
